# %% [markdown]
# <h1 style="text-align: center;">Universidad Centroamericana "José Simeón Cañas"</h1>
# <h1 style="text-align: center;">Proyecto final. Análisis Numérico.</h1>
# <h2 style="text-align: center;">Ciclo 01-18.</h2>
# <h3 style="text-align: center;">Ing. Daniel Augusto Sosa Gonzalez</h3>
#
# <br>
# <img src="images/logo_uca.png" alt="Logo_UCA">
# <br>
#
# <h2 style="text-align: center;">Integrantes:</h2>
# <h3 style="text-align: center;">Gomar Aguilar, Katherine Ivania------------------00011616</h3>
# <h3 style="text-align: center;">Hernández Torres, Douglas Antonio-------------00004516</h3>
# <h3 style="text-align: center;">Linares De Paz, John Vladimir----------------------00005016</h3>
# <h3 style="text-align: center;">Minero Dubón, Carlos Antonio----------------------00058016</h3>
# <h3 style="text-align: center;">Morales Alfaro, Karla Beatriz-------------------------00022516</h3>
# <h3 style="text-align: center;">Ramirez Mirón, Erika Stephanie---------------------00157516</h3>
# <br><br>
# <h2 style="text-align: center;">Antiguo Cuscatlán, 4 de julio de 2018</h2>

# %% [markdown]
# # Contenido
#
# <ol style="font-weight: bold; font-size:20px">
#   <li> Módulo de Interpolación y aproximación polinomial.
#     <br>
#     <ul style="font-weight: normal; font-size:1em">
#       <li><a href="Modulo_Interpolacion_Polinomial/Interpolacion_Lagrange/Lagrange.ipynb">Interpolación lineal de Lagrange.</a></li>
#       <li><a href="Modulo_Interpolacion_Polinomial/Diferencias_Divididas/DIferencias_Divididas.ipynb">Interpolación por Diferencias divididas de Newton.</a></li>
#     </ul>
#     <br>
#   </li>
#   <li> Módulo de Interpolación por Minimos Cuadrados.
#     <br>
#     <ul style="font-weight: normal; font-size:1em">
#       <li>Caso Discreto.
#         <br>
#         <br>
#         <ul>
#           <li>Aproximación Polinomial.</li>
#           <li>Aproximación Exponencial.</li>
#           <li>Aproximación Potencial.</li>
#           <li>Aproximación Logarítmica.</li>
#         </ul>
#         <br>
#       </li>
#       <li>Caso Continuo.</li>
#     </ul>
#     <br>
#   </li>
#   <li> Módulo de Derivación e Integración Numérico.
#     <br>
#     <ul style="font-weight: normal; font-size:1em">
#       <li>Derivación.
#         <br>
#           <br>
#         <ul>
#           <li><a href="Modulo_Derivacion_Integracion/Derivacion/Progresivas.ipynb">Diferencias Progresivas.</a></li>
#           <li><a href="Modulo_Derivacion_Integracion/Derivacion/Centrales.ipynb">Diferencias Centrales.</a></li>
#         </ul>
#         <br>
#       </li>
#       <li>Integración.
#         <br>
#         <br>
#         <ul>
#           <li>Método del Trapecio.
#             <br>
#               <br>
#             <ul>
#               <li><a href="Modulo_Derivacion_Integracion/Integracion/1_Metodo_Trapecio_Simple.ipynb">Integrales Simples.</a></li>
#               <li><a href="Modulo_Derivacion_Integracion/Integracion/2_Metodo_Trapecio_Dobles.ipynb">Integrales Dobles.</a></li>
#               <li><a href="Modulo_Derivacion_Integracion/Integracion/3_Metodo_Trapecio_Triples.ipynb">Integrales Triples.</a></li>
#             </ul>
#             <br>
#           </li>
#           <li>Método de Simpson
#             <br>
#             <br>
#             <ul>
#               <li><a href="Modulo_Derivacion_Integracion/Integracion/4_Metodo_Simpson_Simple.ipynb">Integrales Simples.</a></li>
#               <li><a href="Modulo_Derivacion_Integracion/Integracion/5_Metodo_Simpson_Dobles.ipynb">Integrales Dobles.</a></li>
#               <li><a href="Modulo_Derivacion_Integracion/Integracion/6_Metodo_Simpson_Triples.ipynb">Integrales Triples.</a></li>
#             </ul>
#           </li>
#         </ul>
#       </li>
#     </ul>
#   </li>
# </ol>
